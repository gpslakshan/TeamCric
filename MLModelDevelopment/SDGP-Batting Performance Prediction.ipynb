# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df = pd.read_excel(r'C:\Users\user\Documents\SDGP\cricket_data.xlsx', 'batting')
df
# Out:
#                  player player_role      R    BF   4S    6S      SR team_name  \
# 0        Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1           Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2             Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3         Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4       Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# ...                 ...         ...    ...   ...  ...   ...     ...       ...
# 4667        Nurul Hasan          WK   22.0  21.0  3.0   0.0  104.76       BAN
# 4668     Shamim Hossain      BAT-AR    NaN   NaN  NaN   NaN     NaN       BAN
# 4669  Mustafizur Rahman        BOWL    NaN   NaN  NaN   NaN     NaN       BAN
# 4670     Shoriful Islam        BOWL    NaN   NaN  NaN   NaN     NaN       BAN
# 4671        Nasum Ahmed        BOWL    NaN   NaN  NaN   NaN     NaN       BAN
#
#      opp_name       teams                          venue
# 0          WI    NZ vs WI      Bay Oval, Mount Maunganui
# 1          WI    NZ vs WI      Bay Oval, Mount Maunganui
# 2          WI    NZ vs WI      Bay Oval, Mount Maunganui
# 3          WI    NZ vs WI      Bay Oval, Mount Maunganui
# 4          WI    NZ vs WI      Bay Oval, Mount Maunganui
# ...       ...         ...                            ...
# 4667      AUS  BAN vs AUS  Shere Bangla National Stadium
# 4668      AUS  BAN vs AUS  Shere Bangla National Stadium
# 4669      AUS  BAN vs AUS  Shere Bangla National Stadium
# 4670      AUS  BAN vs AUS  Shere Bangla National Stadium
# 4671      AUS  BAN vs AUS  Shere Bangla National Stadium
#
# [4672 rows x 11 columns]

# %%
df.shape
# Out:
# (4672, 11)

# %%
df.columns
# Out:
# Index(['player', 'player_role', 'R', 'BF', '4S', '6S', 'SR', 'team_name',
#        'opp_name', 'teams', 'venue'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# player           0
# player_role      0
# R              932
# BF             932
# 4S             932
# 6S             932
# SR             932
# team_name        4
# opp_name         4
# teams            2
# venue            2
# dtype: int64

# %%
df['player'].nunique()
# Out:
# 314

# %%
df['player'].unique()
# Out:
# array(['Martin Guptill', 'Colin Munro', 'Tom Bruce', 'Anaru Kitchen',
#        'Kane Williamson', 'Glenn Phillips', 'Mitchell Santner',
#        'Chadwick Walton', 'Chris Gayle', 'Andre Fletcher',
#        'Rovman Powell', 'Shimron Hetmeyer', 'Carlos Brathwaite',
#        'Ashley Nurse', 'Rayad Emrit', 'Jerome Taylor', 'Samuel Badree',
#        'Fakhar Zaman', 'Umar Amin', 'Mohammad Nawaz', 'Haris Sohail',
#        'Babar Azam', 'Sarfaraz Ahmed', 'Shadab Khan', 'Faheem Ashraf',
#        'Hasan Ali', 'Mohammad Amir', 'Rumman Raees', 'Ross Taylor',
#        'Ahmed Shehzad', 'Colin de Grandhomme', 'Ben Wheeler', 'Ish Sodhi',
#        'Seth Rance', 'Trent Boult', 'Aamer Yamin', 'Tom Blundell',
#        'Tim Southee', 'David Warner', "D'Arcy Short", 'Chris Lynn',
#        'Glenn Maxwell', 'Alex Carey', 'Jason Roy', 'Alex Hales',
#        'Dawid Malan', 'Eoin Morgan', 'Jos Buttler', 'Sam Billings',
#        'David Willey', 'Chris Jordan', 'Adil Rashid', 'Tom Curran',
#        'Mark Wood', 'Marcus Stoinis', 'Travis Head', 'James Vince',
#        'Aaron Finch', 'Mark Chapman', 'Tim Seifert', 'Liam Plunkett',
#        'Zakir Hasan', 'Soumya Sarkar', 'Mushfiqur Rahim', 'Afif Hossain',
#        'Mahmudullah', 'Sabbir Rahman', 'Ariful Haque', 'Kusal Mendis',
#        'Danushka Gunathilaka', 'Upul Tharanga', 'Dasun Shanaka',
#        'Niroshan Dickwella', 'Thisara Perera', 'Rohit Sharma',
#        'Shikhar Dhawan', 'Suresh Raina', 'Virat Kohli', 'Manish Pandey',
#        'M S Dhoni', 'Hardik Pandya', 'JJ Smuts', 'Reeza Hendricks',
#        'Jean-Paul Duminy', 'David Miller', 'Farhaan Behardien',
#        'Heinrich Klaasen', 'Andile Phehlukwayo', 'Chris Morris',
#        'Dane Paterson', 'Junior Dala', 'Tabraiz Shamsi',
#        'Dinesh Chandimal', 'Tamim Iqbal', 'Mohammad Mithun',
#        'Mohammad Saifuddin', 'Mahedi Hasan', 'Mustafizur Rahman',
#        'Abu Jayed', 'Nazmul Islam', 'Liam Dawson', 'Ashton Agar',
#        'Dinesh Karthik', 'Axar Patel', 'Bhuvneshwar Kumar',
#        'Christiaan Jonker', 'Rishabh Pant', 'Kusal Perera', 'Liton Das',
#        'Mehidy Hasan', 'Taskin Ahmed', 'Rubel Hossain', 'Jeevan Mendis',
#        'Akila Dananjaya', 'Suranga Lakmal', 'Dushmantha Chameera',
#        'Nuwan Pradeep', 'KL Rahul', 'Abu Hider', 'Isuru Udana',
#        'Shakib Al Hasan', 'Vijay Shankar', 'Washington Sundar',
#        'Hussain Talat', 'Shoaib Malik', 'Asif Ali', 'Marlon Samuels',
#        'Jason Mohammed', 'Denesh Ramdin', 'Keemo Paul',
#        'Kesrick Williams', 'Odean Smith', 'Joe Root', 'Jonny Bairstow',
#        'Moeen Ali', 'Andrew Tye', 'Kane Richardson', 'Mitchell Swepson',
#        'Billy Stanlake', 'Evin Lewis', 'Andre Russell', 'Quinton de Kock',
#        'Hashim Amla', 'Kagiso Rabada', 'Lungi Ngidi',
#        'Dhananjaya de Silva', 'Angelo Mathews', 'Mohammad Hafeez',
#        'Imad Wasim', 'Ben McDermott', 'Nathan Coulter-Nile', 'Adam Zampa',
#        'Mitchell Marsh', 'Ben Stokes', 'Joe Denly', 'Kamindu Mendis',
#        'M Amila Aponso', 'Lasith Malinga', 'Lakshan Sandakan',
#        'Sahibzada Farhan', 'Corey Anderson', 'Adam Milne', 'Shai Hope',
#        'Kieron Pollard', 'Darren Bravo', 'Fabian Allen', 'Khary Pierre',
#        'Krunal Pandya', 'Nicholas Pooran', 'Oshane Thomas',
#        'Faf du Plessis', 'Kuldeep Yadav', 'Henry Nicholls',
#        'Douglas Bracewell', 'Scott Kuggeleijn', 'Lockie Ferguson',
#        'Sadeera Samarawickrama', 'Kasun Rajitha', 'Lahiru Kumara',
#        'Gihahn Cloete', 'Rassie van der Dussen', 'Beuran Hendricks',
#        'Mohammad Rizwan', 'Usman Shinwari', 'Janneman Malan',
#        'Lutho Sipamla', 'Shaheen Shah Afridi', 'Daryl Mitchell',
#        'Yuzvendra Chahal', 'Khaleel Ahmed', 'Umesh Yadav',
#        'Mayank Markande', 'Jasprit Bumrah', 'Peter Handscomb',
#        'Ashton Turner', 'Pat Cummins', 'Jhye Richardson',
#        'Jason Behrendorff', 'Siddarth Kaul', 'Jason Holder',
#        'Sheldon Cottrell', 'Devendra Bishoo', 'Obed McCoy',
#        'Avishka Fernando', 'Angelo Perera', 'Jeffrey Vandersay',
#        'Dale Steyn', 'Imran Tahir', 'Aiden Markram', 'Dwaine Pretorius',
#        'Sinethemba Qeshile', 'Imam-ul-Haq', 'Mohammad Hasnain',
#        'Ben Duckett', 'Ben Foakes', 'Jofra Archer', 'John Campbell',
#        'Sunil Narine', 'Ravindra Jadeja', 'Navdeep Saini',
#        'Shehan Jayasuriya', 'Wanindu Hasaranga', 'Shreyas Iyer',
#        'Deepak Chahar', 'Temba Bavuma', 'Bjorn Fortuin',
#        'Bhanuka Rajapaksa', 'Oshada Fernando', 'Lahiru Madushanka',
#        'Iftikhar Ahmed', 'Wahab Riaz', 'Steve Smith', 'Mitchell Starc',
#        'Mohammad Irfan', 'Shivam Dube', 'Mohammad Naim',
#        'Mosaddeck Hossain', 'Aminul Islam', 'Shafiul Islam',
#        'Al-Amin Hossain', 'James Neesham', 'Sam Curran', 'Lewis Gregory',
#        'Saqib Mahmood', 'Pat Brown', 'Blair Tickner', 'Tom Banton',
#        'Matt Parkinson', 'Lendl Simmons', 'Brandon King', 'Hayden Walsh',
#        'Mohammed Shami', 'Shardul Thakur', 'Sanju Samson',
#        'Hamish Bennett', 'Ahsan Ali', 'Haris Rauf', 'Matthew Wade',
#        'Pite van Biljon', 'Anrich Nortje', 'Dwayne Bravo', 'Haider Ali',
#        'Josh Hazlewood', 'Devon Conway', 'Kyle Jamieson', 'George Linde',
#        'Kyle Mayers', 'Thangarasu Natarajan', 'Moises Henriques',
#        'Sean Abbott', 'Daniel Sams', 'Abdullah Shafique', 'Khushdil Shah',
#        'Jacob Duffy', 'Usman Qadir', 'Jacques Snyman', 'Glenton Stuurman',
#        'Josh Philippe', 'Pathum Nissanka', 'Ashen Bandara',
#        'Kevin Sinclair', 'Fidel Edwards', 'Riley Meredith',
#        'Ishan Kishan', 'Suryakumar Yadav', 'Finn Allen', 'Will Young',
#        'Shoriful Islam', 'Nasum Ahmed', 'Wihan Lubbe', 'Sisanda Magala',
#        'Lizaad Williams', 'Sharjeel Khan', 'Liam Livingstone',
#        'Chris Woakes', 'Binura Fernando', 'Dan Christian', 'Akeal Hosein',
#        'Sohaib Maqsood', 'Azam Khan', 'Prithvi Shaw',
#        'Varun Chakravarthy', 'Minod Bhanuka', 'Charith Asalanka',
#        'Chamika Karunaratne', 'Ruturaj Gaikwad', 'Devdutt Padikkal',
#        'Nitish Rana', 'Rahul Chahar', 'Chetan Sakariya',
#        'Sandeep Warrier', 'Ramesh Mendis', 'Nurul Hasan',
#        'Shamim Hossain'], dtype=object)

# %%
df['team_name'].nunique()
# Out:
# 9

# %%
df['team_name'].unique()
# Out:
# array(['NZ', 'WI', 'PAK', 'AUS', 'ENG', 'BAN', 'SL', 'IND', 'SA', nan],
#       dtype=object)

# %%
df['venue'].nunique()
# Out:
# 52

# %%
df['venue'].unique()
# Out:
# array(['Bay Oval, Mount Maunganui', 'Westpac Trust Stadium', 'Eden Park',
#        'Bay Oval', 'Sydney Cricket Ground', 'Bellerive Oval',
#        'Melbourne Cricket Ground', 'Westpac Stadium',
#        'Shere Bangla National Stadium', 'Wanderers Stadium',
#        'Sylhet Stadium', 'Seddon Park', 'SuperSport Park', 'Newlands',
#        'R Premadasa Stadium', 'National Stadium (Karachi)', 'Edgbaston',
#        'Old Trafford', 'Sophia Gardens', 'Warner Park',
#        'Central Broward Regional Park', 'Sheikh Zayed Stadium',
#        'Dubai International Cricket Stadium', 'Eden Gardens',
#        'Ekana International Cricket Stadium', 'Metricon Stadium',
#        'Brisbane Cricket Ground',
#        'Dr YS Rajasekhara Reddy Cricket Stadium', 'M Chinnaswamy Stadium',
#        'Daren Sammy National Cricket Stadium',
#        'Pallekele International Cricket Stadium', 'Gaddafi Stadium',
#        'Arun Jaitley Stadium', 'Manuka Oval', 'Saxton Oval',
#        'Greenfield International Stadium', 'Wankhede Stadium',
#        'Holkar Cricket Stadium',
#        'Maharashtra Cricket Association Stadium', 'Buffalo Park',
#        'Kingsmead', "St George's Park", 'The Rose Bowl', 'Boland Park',
#        'McLean Park', 'Hagley Oval', 'University Oval', nan,
#        'Coolidge Cricket Ground', 'Narendra Modi Stadium',
#        'National Cricket Stadium (Grenada)', 'Trent Bridge', 'Headingley'],
#       dtype=object)

# %%
players_per_team = df.groupby(['team_name'])['player'].nunique().reset_index().rename(columns={'player': 'no. of players'})
players_per_team
# Out:
#   team_name  no. of players
# 0       AUS              32
# 1       BAN              29
# 2       ENG              30
# 3       IND              41
# 4        NZ              32
# 5       PAK              36
# 6        SA              37
# 7        SL              38
# 8        WI              40

# %%
sns.barplot(x="team_name", y="no. of players", ci=None, data=players_per_team)
plt.xlabel('Team Name', fontsize=10)
plt.ylabel('No. of Players', fontsize=10)
plt.title("Total players per team", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Total players per team')

# %% [markdown]
# # Data Preprocessing

# %%
df = df.dropna()
df
# Out:
#                player player_role      R    BF   4S    6S      SR team_name  \
# 0      Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1         Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2           Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3       Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4     Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# ...               ...         ...    ...   ...  ...   ...     ...       ...
# 4663  Shakib Al Hasan      BAT-AR   26.0  17.0  4.0   0.0  152.94       BAN
# 4664     Mahedi Hasan      BAT-AR   23.0  24.0  0.0   1.0   95.83       BAN
# 4665      Mahmudullah      BAT-AR    0.0   4.0  0.0   0.0    0.00       BAN
# 4666     Afif Hossain      BAT-AR   37.0  31.0  5.0   1.0  119.35       BAN
# 4667      Nurul Hasan          WK   22.0  21.0  3.0   0.0  104.76       BAN
#
#      opp_name       teams                          venue
# 0          WI    NZ vs WI      Bay Oval, Mount Maunganui
# 1          WI    NZ vs WI      Bay Oval, Mount Maunganui
# 2          WI    NZ vs WI      Bay Oval, Mount Maunganui
# 3          WI    NZ vs WI      Bay Oval, Mount Maunganui
# 4          WI    NZ vs WI      Bay Oval, Mount Maunganui
# ...       ...         ...                            ...
# 4663      AUS  BAN vs AUS  Shere Bangla National Stadium
# 4664      AUS  BAN vs AUS  Shere Bangla National Stadium
# 4665      AUS  BAN vs AUS  Shere Bangla National Stadium
# 4666      AUS  BAN vs AUS  Shere Bangla National Stadium
# 4667      AUS  BAN vs AUS  Shere Bangla National Stadium
#
# [3740 rows x 11 columns]

# %%
df = df.drop(index = df[df['player_role'] == 'BOWL'].index)  #Removing Bowlers from the batting dataframe
df.head(20)
# Out:
#                player player_role      R    BF   4S    6S      SR team_name  \
# 0      Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1         Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2           Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3       Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4     Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# 5      Glenn Phillips          WK    7.0   4.0  0.0   1.0  175.00        NZ
# 6    Mitchell Santner     BOWL-AR    6.0   1.0  0.0   1.0  600.00        NZ
# 7     Chadwick Walton          WK    0.0   1.0  0.0   0.0    0.00        WI
# 8         Chris Gayle         BAT    0.0   2.0  0.0   0.0    0.00        WI
# 9      Andre Fletcher          WK   46.0  32.0  4.0   3.0  143.75        WI
# 10      Rovman Powell         BAT   16.0   8.0  4.0   0.0  200.00        WI
# 11   Shimron Hetmeyer         BAT    7.0   3.0  0.0   1.0  233.33        WI
# 12  Carlos Brathwaite     BOWL-AR   15.0  14.0  1.0   1.0  107.14        WI
# 14        Rayad Emrit     BOWL-AR    5.0   6.0  0.0   0.0   83.33        WI
# 17       Fakhar Zaman         BAT    3.0   4.0  0.0   0.0   75.00       PAK
# 18          Umar Amin      BAT-AR    0.0   7.0  0.0   0.0    0.00       PAK
# 19     Mohammad Nawaz     BOWL-AR    7.0   9.0  1.0   0.0   77.78       PAK
# 20       Haris Sohail      BAT-AR    9.0  10.0  1.0   0.0   90.00       PAK
# 21         Babar Azam         BAT   41.0  41.0  1.0   1.0  100.00       PAK
# 22     Sarfaraz Ahmed          WK    9.0  14.0  1.0   0.0   64.29       PAK
#
#    opp_name      teams                      venue
# 0        WI   NZ vs WI  Bay Oval, Mount Maunganui
# 1        WI   NZ vs WI  Bay Oval, Mount Maunganui
# 2        WI   NZ vs WI  Bay Oval, Mount Maunganui
# 3        WI   NZ vs WI  Bay Oval, Mount Maunganui
# 4        WI   NZ vs WI  Bay Oval, Mount Maunganui
# 5        WI   NZ vs WI  Bay Oval, Mount Maunganui
# 6        WI   NZ vs WI  Bay Oval, Mount Maunganui
# 7        NZ   NZ vs WI  Bay Oval, Mount Maunganui
# 8        NZ   NZ vs WI  Bay Oval, Mount Maunganui
# 9        NZ   NZ vs WI  Bay Oval, Mount Maunganui
# 10       NZ   NZ vs WI  Bay Oval, Mount Maunganui
# 11       NZ   NZ vs WI  Bay Oval, Mount Maunganui
# 12       NZ   NZ vs WI  Bay Oval, Mount Maunganui
# 14       NZ   NZ vs WI  Bay Oval, Mount Maunganui
# 17       NZ  NZ vs PAK      Westpac Trust Stadium
# 18       NZ  NZ vs PAK      Westpac Trust Stadium
# 19       NZ  NZ vs PAK      Westpac Trust Stadium
# 20       NZ  NZ vs PAK      Westpac Trust Stadium
# 21       NZ  NZ vs PAK      Westpac Trust Stadium
# 22       NZ  NZ vs PAK      Westpac Trust Stadium

# %%
df.shape
# Out:
# (3242, 11)

# %%
df.isnull().sum()
# Out:
# player         0
# player_role    0
# R              0
# BF             0
# 4S             0
# 6S             0
# SR             0
# team_name      0
# opp_name       0
# teams          0
# venue          0
# dtype: int64

# %%
df.describe()
# Out:
#                  R           BF           4S           6S           SR
# count  3242.000000  3242.000000  3242.000000  3242.000000  3242.000000
# mean     20.888957    15.729180     1.773597     0.843307   115.823208
# std      21.047485    13.216357     2.146143     1.364739    67.730826
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     5.000000     0.000000     0.000000    75.000000
# 50%      14.000000    12.000000     1.000000     0.000000   116.670000
# 75%      31.000000    23.000000     3.000000     1.000000   154.170000
# max     113.000000    64.000000    13.000000    10.000000   600.000000

# %%
r_conditions = [
    (df['R'] >= 30),
    (df['R'] >= 20) & (df['R'] < 30),
    (df['R'] >= 10) & (df['R'] < 20),
    (df['R'] > 0) & (df['R'] < 10),
    (df['R'] == 0)
]


r_values = [
    1,
    0.75,
    0.5,
    0.25,
    0
]

df['R_points'] = np.select(r_conditions, r_values)
df
# Out:
#                player player_role      R    BF   4S    6S      SR team_name  \
# 0      Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1         Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2           Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3       Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4     Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# ...               ...         ...    ...   ...  ...   ...     ...       ...
# 4663  Shakib Al Hasan      BAT-AR   26.0  17.0  4.0   0.0  152.94       BAN
# 4664     Mahedi Hasan      BAT-AR   23.0  24.0  0.0   1.0   95.83       BAN
# 4665      Mahmudullah      BAT-AR    0.0   4.0  0.0   0.0    0.00       BAN
# 4666     Afif Hossain      BAT-AR   37.0  31.0  5.0   1.0  119.35       BAN
# 4667      Nurul Hasan          WK   22.0  21.0  3.0   0.0  104.76       BAN
#
#      opp_name       teams                          venue  R_points
# 0          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00
# 1          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00
# 2          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.75
# 3          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.25
# 4          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.50
# ...       ...         ...                            ...       ...
# 4663      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75
# 4664      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75
# 4665      AUS  BAN vs AUS  Shere Bangla National Stadium      0.00
# 4666      AUS  BAN vs AUS  Shere Bangla National Stadium      1.00
# 4667      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75
#
# [3242 rows x 12 columns]

# %%
fours_conditions = [
    (df['4S'] >= 10),
    (df['4S'] >= 5) & (df['4S'] < 10),
    (df['4S'] >= 2) & (df['4S'] < 5),
    (df['4S'] == 1),
    (df['4S'] == 0)
]


fours_values = [
    1,
    0.75,
    0.5,
    0.25,
    0
]

df['4S_points'] = np.select(fours_conditions, fours_values)
df
# Out:
#                player player_role      R    BF   4S    6S      SR team_name  \
# 0      Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1         Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2           Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3       Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4     Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# ...               ...         ...    ...   ...  ...   ...     ...       ...
# 4663  Shakib Al Hasan      BAT-AR   26.0  17.0  4.0   0.0  152.94       BAN
# 4664     Mahedi Hasan      BAT-AR   23.0  24.0  0.0   1.0   95.83       BAN
# 4665      Mahmudullah      BAT-AR    0.0   4.0  0.0   0.0    0.00       BAN
# 4666     Afif Hossain      BAT-AR   37.0  31.0  5.0   1.0  119.35       BAN
# 4667      Nurul Hasan          WK   22.0  21.0  3.0   0.0  104.76       BAN
#
#      opp_name       teams                          venue  R_points  4S_points
# 0          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.75
# 1          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.50
# 2          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.75       0.50
# 3          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.25       0.00
# 4          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.50       0.50
# ...       ...         ...                            ...       ...        ...
# 4663      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
# 4664      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.00
# 4665      AUS  BAN vs AUS  Shere Bangla National Stadium      0.00       0.00
# 4666      AUS  BAN vs AUS  Shere Bangla National Stadium      1.00       0.75
# 4667      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
#
# [3242 rows x 13 columns]

# %%
sixes_conditions = [
    (df['6S'] >= 6),
    (df['6S'] >= 3) & (df['6S'] < 6),
    (df['6S'] == 2),
    (df['6S'] == 1),
    (df['6S'] == 0)
]


sixes_values = [
    1,
    0.75,
    0.5,
    0.25,
    0
]

df['6S_points'] = np.select(sixes_conditions, sixes_values)
df
# Out:
#                player player_role      R    BF   4S    6S      SR team_name  \
# 0      Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1         Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2           Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3       Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4     Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# ...               ...         ...    ...   ...  ...   ...     ...       ...
# 4663  Shakib Al Hasan      BAT-AR   26.0  17.0  4.0   0.0  152.94       BAN
# 4664     Mahedi Hasan      BAT-AR   23.0  24.0  0.0   1.0   95.83       BAN
# 4665      Mahmudullah      BAT-AR    0.0   4.0  0.0   0.0    0.00       BAN
# 4666     Afif Hossain      BAT-AR   37.0  31.0  5.0   1.0  119.35       BAN
# 4667      Nurul Hasan          WK   22.0  21.0  3.0   0.0  104.76       BAN
#
#      opp_name       teams                          venue  R_points  4S_points  \
# 0          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.75
# 1          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.50
# 2          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.75       0.50
# 3          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.25       0.00
# 4          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.50       0.50
# ...       ...         ...                            ...       ...        ...
# 4663      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
# 4664      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.00
# 4665      AUS  BAN vs AUS  Shere Bangla National Stadium      0.00       0.00
# 4666      AUS  BAN vs AUS  Shere Bangla National Stadium      1.00       0.75
# 4667      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
#
#       6S_points
# 0          0.50
# 1          1.00
# 2          0.25
# 3          0.25
# 4          0.25
# ...         ...
# 4663       0.00
# 4664       0.25
# 4665       0.00
# 4666       0.25
# 4667       0.00
#
# [3242 rows x 14 columns]

# %%
sr_conditions = [
    (df['SR'] >= 155),
    (df['SR'] >= 115) & (df['SR'] < 155),
    (df['SR'] >= 75) & (df['SR'] < 115),
    (df['SR'] >= 1) & (df['SR'] < 75),
    (df['SR'] == 0)
]


sr_values = [
    1,
    0.75,
    0.5,
    0.25,
    0
]

df['SR_points'] = np.select(sr_conditions, sr_values)
df
# Out:
#                player player_role      R    BF   4S    6S      SR team_name  \
# 0      Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1         Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2           Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3       Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4     Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# ...               ...         ...    ...   ...  ...   ...     ...       ...
# 4663  Shakib Al Hasan      BAT-AR   26.0  17.0  4.0   0.0  152.94       BAN
# 4664     Mahedi Hasan      BAT-AR   23.0  24.0  0.0   1.0   95.83       BAN
# 4665      Mahmudullah      BAT-AR    0.0   4.0  0.0   0.0    0.00       BAN
# 4666     Afif Hossain      BAT-AR   37.0  31.0  5.0   1.0  119.35       BAN
# 4667      Nurul Hasan          WK   22.0  21.0  3.0   0.0  104.76       BAN
#
#      opp_name       teams                          venue  R_points  4S_points  \
# 0          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.75
# 1          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.50
# 2          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.75       0.50
# 3          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.25       0.00
# 4          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.50       0.50
# ...       ...         ...                            ...       ...        ...
# 4663      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
# 4664      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.00
# 4665      AUS  BAN vs AUS  Shere Bangla National Stadium      0.00       0.00
# 4666      AUS  BAN vs AUS  Shere Bangla National Stadium      1.00       0.75
# 4667      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
#
#       6S_points  SR_points
# 0          0.50       1.00
# 1          1.00       1.00
# 2          0.25       1.00
# 3          0.25       1.00
# 4          0.25       1.00
# ...         ...        ...
# 4663       0.00       0.75
# 4664       0.25       0.50
# 4665       0.00       0.00
# 4666       0.25       0.75
# 4667       0.00       0.50
#
# [3242 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# player         0
# player_role    0
# R              0
# BF             0
# 4S             0
# 6S             0
# SR             0
# team_name      0
# opp_name       0
# teams          0
# venue          0
# R_points       0
# 4S_points      0
# 6S_points      0
# SR_points      0
# dtype: int64

# %%
df['performance_index'] = df['R_points'] + df['4S_points'] + df['6S_points'] + df['SR_points']
df
# Out:
#                player player_role      R    BF   4S    6S      SR team_name  \
# 0      Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1         Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2           Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3       Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4     Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# ...               ...         ...    ...   ...  ...   ...     ...       ...
# 4663  Shakib Al Hasan      BAT-AR   26.0  17.0  4.0   0.0  152.94       BAN
# 4664     Mahedi Hasan      BAT-AR   23.0  24.0  0.0   1.0   95.83       BAN
# 4665      Mahmudullah      BAT-AR    0.0   4.0  0.0   0.0    0.00       BAN
# 4666     Afif Hossain      BAT-AR   37.0  31.0  5.0   1.0  119.35       BAN
# 4667      Nurul Hasan          WK   22.0  21.0  3.0   0.0  104.76       BAN
#
#      opp_name       teams                          venue  R_points  4S_points  \
# 0          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.75
# 1          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.50
# 2          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.75       0.50
# 3          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.25       0.00
# 4          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.50       0.50
# ...       ...         ...                            ...       ...        ...
# 4663      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
# 4664      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.00
# 4665      AUS  BAN vs AUS  Shere Bangla National Stadium      0.00       0.00
# 4666      AUS  BAN vs AUS  Shere Bangla National Stadium      1.00       0.75
# 4667      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
#
#       6S_points  SR_points  performance_index
# 0          0.50       1.00               3.25
# 1          1.00       1.00               3.50
# 2          0.25       1.00               2.50
# 3          0.25       1.00               1.50
# 4          0.25       1.00               2.25
# ...         ...        ...                ...
# 4663       0.00       0.75               2.00
# 4664       0.25       0.50               1.50
# 4665       0.00       0.00               0.00
# 4666       0.25       0.75               2.75
# 4667       0.00       0.50               1.75
#
# [3242 rows x 16 columns]

# %%
df.describe()
# Out:
#                  R           BF           4S           6S           SR  \
# count  3242.000000  3242.000000  3242.000000  3242.000000  3242.000000
# mean     20.888957    15.729180     1.773597     0.843307   115.823208
# std      21.047485    13.216357     2.146143     1.364739    67.730826
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     5.000000     0.000000     0.000000    75.000000
# 50%      14.000000    12.000000     1.000000     0.000000   116.670000
# 75%      31.000000    23.000000     3.000000     1.000000   154.170000
# max     113.000000    64.000000    13.000000    10.000000   600.000000
#
#           R_points    4S_points    6S_points    SR_points  performance_index
# count  3242.000000  3242.000000  3242.000000  3242.000000        3242.000000
# mean      0.547656     0.290407     0.188001     0.606107           1.632171
# std       0.336283     0.268963     0.264819     0.314098           1.009633
# min       0.000000     0.000000     0.000000     0.000000           0.000000
# 25%       0.250000     0.000000     0.000000     0.500000           0.750000
# 50%       0.500000     0.250000     0.000000     0.750000           1.500000
# 75%       1.000000     0.500000     0.250000     0.750000           2.500000
# max       1.000000     1.000000     1.000000     1.000000           4.000000

# %%
performance_conditions = [
    (df['performance_index'] >= 2.50),
    (df['performance_index'] >= 1.00) & (df['performance_index'] < 2.50),
    (df['performance_index'] >= 0) & (df['performance_index'] < 1.00),
]


performance_values = [
    2,
    1,
    0
]

df['performance'] = np.select(performance_conditions, performance_values)
df
# Out:
#                player player_role      R    BF   4S    6S      SR team_name  \
# 0      Martin Guptill         BAT   63.0  38.0  5.0   2.0  165.79        NZ
# 1         Colin Munro      BAT-AR  104.0  53.0  3.0  10.0  196.23        NZ
# 2           Tom Bruce      BAT-AR   23.0  14.0  2.0   1.0  164.29        NZ
# 3       Anaru Kitchen         BAT    9.0   3.0  0.0   1.0  300.00        NZ
# 4     Kane Williamson         BAT   19.0   8.0  2.0   1.0  237.50        NZ
# ...               ...         ...    ...   ...  ...   ...     ...       ...
# 4663  Shakib Al Hasan      BAT-AR   26.0  17.0  4.0   0.0  152.94       BAN
# 4664     Mahedi Hasan      BAT-AR   23.0  24.0  0.0   1.0   95.83       BAN
# 4665      Mahmudullah      BAT-AR    0.0   4.0  0.0   0.0    0.00       BAN
# 4666     Afif Hossain      BAT-AR   37.0  31.0  5.0   1.0  119.35       BAN
# 4667      Nurul Hasan          WK   22.0  21.0  3.0   0.0  104.76       BAN
#
#      opp_name       teams                          venue  R_points  4S_points  \
# 0          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.75
# 1          WI    NZ vs WI      Bay Oval, Mount Maunganui      1.00       0.50
# 2          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.75       0.50
# 3          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.25       0.00
# 4          WI    NZ vs WI      Bay Oval, Mount Maunganui      0.50       0.50
# ...       ...         ...                            ...       ...        ...
# 4663      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
# 4664      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.00
# 4665      AUS  BAN vs AUS  Shere Bangla National Stadium      0.00       0.00
# 4666      AUS  BAN vs AUS  Shere Bangla National Stadium      1.00       0.75
# 4667      AUS  BAN vs AUS  Shere Bangla National Stadium      0.75       0.50
#
#       6S_points  SR_points  performance_index  performance
# 0          0.50       1.00               3.25            2
# 1          1.00       1.00               3.50            2
# 2          0.25       1.00               2.50            2
# 3          0.25       1.00               1.50            1
# 4          0.25       1.00               2.25            1
# ...         ...        ...                ...          ...
# 4663       0.00       0.75               2.00            1
# 4664       0.25       0.50               1.50            1
# 4665       0.00       0.00               0.00            0
# 4666       0.25       0.75               2.75            2
# 4667       0.00       0.50               1.75            1
#
# [3242 rows x 17 columns]

# %%
df = df.filter(['player', 'player_role', 'team_name', 'opp_name', 'venue', 'performance'])
df
# Out:
#                player player_role team_name opp_name  \
# 0      Martin Guptill         BAT        NZ       WI
# 1         Colin Munro      BAT-AR        NZ       WI
# 2           Tom Bruce      BAT-AR        NZ       WI
# 3       Anaru Kitchen         BAT        NZ       WI
# 4     Kane Williamson         BAT        NZ       WI
# ...               ...         ...       ...      ...
# 4663  Shakib Al Hasan      BAT-AR       BAN      AUS
# 4664     Mahedi Hasan      BAT-AR       BAN      AUS
# 4665      Mahmudullah      BAT-AR       BAN      AUS
# 4666     Afif Hossain      BAT-AR       BAN      AUS
# 4667      Nurul Hasan          WK       BAN      AUS
#
#                               venue  performance
# 0         Bay Oval, Mount Maunganui            2
# 1         Bay Oval, Mount Maunganui            2
# 2         Bay Oval, Mount Maunganui            2
# 3         Bay Oval, Mount Maunganui            1
# 4         Bay Oval, Mount Maunganui            1
# ...                             ...          ...
# 4663  Shere Bangla National Stadium            1
# 4664  Shere Bangla National Stadium            1
# 4665  Shere Bangla National Stadium            0
# 4666  Shere Bangla National Stadium            2
# 4667  Shere Bangla National Stadium            1
#
# [3242 rows x 6 columns]

# %%
le_player = LabelEncoder()
le_opp_name = LabelEncoder()
le_venue = LabelEncoder()

# %%
df['player_id'] = le_player.fit_transform(df['player'])
df['opp_id'] = le_opp_name.fit_transform(df['opp_name'])
df['venue_id'] = le_venue.fit_transform(df['venue'])
df
# Out:
#                player player_role team_name opp_name  \
# 0      Martin Guptill         BAT        NZ       WI
# 1         Colin Munro      BAT-AR        NZ       WI
# 2           Tom Bruce      BAT-AR        NZ       WI
# 3       Anaru Kitchen         BAT        NZ       WI
# 4     Kane Williamson         BAT        NZ       WI
# ...               ...         ...       ...      ...
# 4663  Shakib Al Hasan      BAT-AR       BAN      AUS
# 4664     Mahedi Hasan      BAT-AR       BAN      AUS
# 4665      Mahmudullah      BAT-AR       BAN      AUS
# 4666     Afif Hossain      BAT-AR       BAN      AUS
# 4667      Nurul Hasan          WK       BAN      AUS
#
#                               venue  performance  player_id  opp_id  venue_id
# 0         Bay Oval, Mount Maunganui            2        122       8         2
# 1         Bay Oval, Mount Maunganui            2         36       8         2
# 2         Bay Oval, Mount Maunganui            2        187       8         2
# 3         Bay Oval, Mount Maunganui            1         10       8         2
# 4         Bay Oval, Mount Maunganui            1        101       8         2
# ...                             ...          ...        ...     ...       ...
# 4663  Shere Bangla National Stadium            1        167       0        38
# 4664  Shere Bangla National Stadium            1        116       0        38
# 4665  Shere Bangla National Stadium            0        117       0        38
# 4666  Shere Bangla National Stadium            2          3       0        38
# 4667  Shere Bangla National Stadium            1        140       0        38
#
# [3242 rows x 9 columns]

# %%
group = df.groupby('team_name')
group

# %%
df_oppositionIDs = df[['opp_name', 'opp_id']]
df_oppositionIDs = df_oppositionIDs.drop_duplicates(subset='opp_name', keep='first')
df_oppositionIDs
# Out:
#     opp_name  opp_id
# 0         WI       8
# 7         NZ       4
# 28       PAK       5
# 66       AUS       0
# 92       ENG       2
# 130       SL       7
# 137      BAN       1
# 158       SA       6
# 165      IND       3

# %%
df_venueIDs = df[['venue', 'venue_id']]
df_venueIDs = df_venueIDs.drop_duplicates(subset='venue', keep='first')
df_venueIDs
# Out:
#                                         venue  venue_id
# 0                   Bay Oval, Mount Maunganui         2
# 17                      Westpac Trust Stadium        51
# 33                                  Eden Park        13
# 50                                   Bay Oval         1
# 66                      Sydney Cricket Ground        42
# 81                             Bellerive Oval         3
# 99                   Melbourne Cricket Ground        26
# 112                           Westpac Stadium        50
# 130             Shere Bangla National Stadium        38
# 158                         Wanderers Stadium        47
# 176                            Sylhet Stadium        43
# 193                               Seddon Park        36
# 208                           SuperSport Park        41
# 236                                  Newlands        31
# 252                       R Premadasa Stadium        34
# 362                National Stadium (Karachi)        30
# 395                                 Edgbaston        14
# 413                              Old Trafford        32
# 427                            Sophia Gardens        39
# 441                               Warner Park        49
# 457             Central Broward Regional Park         7
# 495                      Sheikh Zayed Stadium        37
# 516       Dubai International Cricket Stadium        11
# 586                              Eden Gardens        12
# 603       Ekana International Cricket Stadium        15
# 618                          Metricon Stadium        27
# 634                   Brisbane Cricket Ground         5
# 773   Dr YS Rajasekhara Reddy Cricket Stadium        10
# 795                     M Chinnaswamy Stadium        22
# 817      Daren Sammy National Cricket Stadium         9
# 971   Pallekele International Cricket Stadium        33
# 1037                          Gaddafi Stadium        16
# 1125                     Arun Jaitley Stadium         0
# 1169                              Manuka Oval        24
# 1191                              Saxton Oval        35
# 1213         Greenfield International Stadium        17
# 1235                         Wankhede Stadium        48
# 1257                   Holkar Cricket Stadium        20
# 1279  Maharashtra Cricket Association Stadium        23
# 1389                             Buffalo Park         6
# 1411                                Kingsmead        21
# 1455                         St George's Park        40
# 1565                            The Rose Bowl        44
# 1675                              Boland Park         4
# 1764                              McLean Park        25
# 1830                              Hagley Oval        18
# 1852                          University Oval        46
# 1874                  Coolidge Cricket Ground         8
# 1940                    Narendra Modi Stadium        28
# 2116       National Cricket Stadium (Grenada)        29
# 2204                             Trent Bridge        45
# 2226                               Headingley        19

# %% [markdown]
# #### Sri Lankan Player Details

# %%
df_bat_sl = group.get_group('SL')
df_bat_sl = df_bat_sl[['player', 'player_role', 'player_id']]
df_bat_sl = df_bat_sl.drop_duplicates(subset='player', keep='first')
df_bat_sl
# Out:
#                       player player_role  player_id
# 137             Kusal Mendis         BAT        106
# 138     Danushka Gunathilaka      BAT-AR         42
# 139            Upul Tharanga         BAT        191
# 140            Dasun Shanaka      BAT-AR         45
# 141       Niroshan Dickwella          WK        138
# 142           Thisara Perera     BOWL-AR        183
# 181         Dinesh Chandimal          WK         54
# 260             Kusal Perera          WK        107
# 288            Jeevan Mendis     BOWL-AR         91
# 332              Isuru Udana     BOWL-AR         81
# 489      Dhananjaya de Silva      BAT-AR         53
# 490           Angelo Mathews      BAT-AR         14
# 548           Kamindu Mendis      BAT-AR        100
# 675   Sadeera Samarawickrama          WK        157
# 862         Avishka Fernando         BAT         20
# 865            Angelo Perera      BAT-AR         15
# 998        Shehan Jayasuriya      BAT-AR        170
# 999        Wanindu Hasaranga     BOWL-AR        194
# 1039       Bhanuka Rajapaksa         BAT         27
# 1041         Oshada Fernando         BAT        141
# 1043       Lahiru Madushanka      BAT-AR        109
# 1876         Pathum Nissanka         BAT        142
# 2260           Minod Bhanuka          WK        125
# 2262        Charith Asalanka     BOWL-AR         31

# %% [markdown]
# #### England Player Details

# %%
df_bat_eng = group.get_group('ENG')
df_bat_eng = df_bat_eng[['player', 'player_role', 'player_id']]
df_bat_eng = df_bat_eng.drop_duplicates(subset='player', keep='first')
df_bat_eng
# Out:
#                 player player_role  player_id
# 81           Jason Roy         BAT         89
# 82          Alex Hales         BAT          8
# 83         Dawid Malan         BAT         49
# 84         Eoin Morgan         BAT         58
# 85         Jos Buttler          WK         97
# 86        Sam Billings          WK        159
# 87        David Willey     BOWL-AR         48
# 90          Tom Curran     BOWL-AR        188
# 102        James Vince         BAT         85
# 200        Liam Dawson     BOWL-AR        112
# 399           Joe Root         BAT         94
# 400     Jonny Bairstow          WK         96
# 401          Moeen Ali      BAT-AR        128
# 538         Ben Stokes      BAT-AR         26
# 540          Joe Denly      BAT-AR         93
# 917        Ben Duckett         BAT         24
# 1163        Sam Curran     BOWL-AR        160
# 1164     Lewis Gregory     BOWL-AR        111
# 1202        Tom Banton          WK        185
# 2110  Liam Livingstone         BAT        113

# %% [markdown]
# #### Australian Player Details

# %%
df_bat_aus = group.get_group('AUS')
df_bat_aus = df_bat_aus[['player', 'player_role', 'player_id']]
df_bat_aus = df_bat_aus.drop_duplicates(subset='player', keep='first')
df_bat_aus
# Out:
#                 player player_role  player_id
# 76        David Warner         BAT         47
# 77        D'Arcy Short         BAT         39
# 78          Chris Lynn         BAT         33
# 79       Glenn Maxwell      BAT-AR         68
# 80          Alex Carey          WK          7
# 96      Marcus Stoinis      BAT-AR        119
# 97         Travis Head      BAT-AR        189
# 111        Aaron Finch         BAT          0
# 233        Ashton Agar     BOWL-AR         17
# 509      Ben McDermott          WK         25
# 527     Mitchell Marsh      BAT-AR        126
# 788    Peter Handscomb          WK        143
# 789      Ashton Turner      BAT-AR         18
# 792    Jhye Richardson     BOWL-AR         92
# 1072       Steve Smith         BAT        178
# 1436      Matthew Wade          WK        123
# 1713  Moises Henriques      BAT-AR        135
# 1715       Sean Abbott     BOWL-AR        164
# 1726       Daniel Sams     BOWL-AR         41
# 1843     Josh Philippe          WK         98
# 2166     Dan Christian     BOWL-AR         40

# %% [markdown]
# #### New-zealand Player Details

# %%
df_bat_nz = group.get_group('NZ')
df_bat_nz = df_bat_nz[['player', 'player_role', 'player_id']]
df_bat_nz = df_bat_nz.drop_duplicates(subset='player', keep='first')
df_bat_nz
# Out:
#                    player player_role  player_id
# 0          Martin Guptill         BAT        122
# 1             Colin Munro      BAT-AR         36
# 2               Tom Bruce      BAT-AR        187
# 3           Anaru Kitchen         BAT         10
# 4         Kane Williamson         BAT        101
# 5          Glenn Phillips          WK         69
# 6        Mitchell Santner     BOWL-AR        127
# 32            Ross Taylor         BAT        153
# 44    Colin de Grandhomme      BAT-AR         37
# 64           Tom Blundell          WK        186
# 116          Mark Chapman      BAT-AR        120
# 118           Tim Seifert          WK        184
# 568        Corey Anderson      BAT-AR         38
# 666        Henry Nicholls         BAT         75
# 670      Scott Kuggeleijn      BAT-AR        163
# 732        Daryl Mitchell     BOWL-AR         44
# 1153        James Neesham      BAT-AR         84
# 1622         Devon Conway          WK         52
# 1985           Finn Allen          WK         65
# 1987           Will Young      BAT-AR        197

# %% [markdown]
# #### South African Player Details

# %%
df_bat_sa = group.get_group('SA')
df_bat_sa = df_bat_sa[['player', 'player_role', 'player_id']]
df_bat_sa = df_bat_sa.drop_duplicates(subset='player', keep='first')
df_bat_sa
# Out:
#                      player player_role  player_id
# 165                JJ Smuts      BAT-AR         82
# 166         Reeza Hendricks         BAT        150
# 167        Jean-Paul Duminy      BAT-AR         90
# 168            David Miller         BAT         46
# 169       Farhaan Behardien      BAT-AR         64
# 170        Heinrich Klaasen          WK         74
# 171      Andile Phehlukwayo     BOWL-AR         11
# 172            Chris Morris     BOWL-AR         34
# 249       Christiaan Jonker         BAT         35
# 475         Quinton de Kock          WK        146
# 476             Hashim Amla         BAT         73
# 620          Faf du Plessis         BAT         61
# 686           Gihahn Cloete          WK         67
# 688   Rassie van der Dussen         BAT        147
# 708          Janneman Malan         BAT         86
# 883           Aiden Markram         BAT          6
# 1028           Temba Bavuma         BAT        182
# 1395       Dwaine Pretorius     BOWL-AR         56
# 1449        Pite van Biljon          WK        144
# 1637           George Linde      BAT-AR         66
# 1799         Jacques Snyman      BAT-AR         83
# 2030            Wihan Lubbe      BAT-AR        196

# %% [markdown]
# #### West Indies Player Details

# %%
df_bat_wi = group.get_group('WI')
df_bat_wi = df_bat_wi[['player', 'player_role', 'player_id']]
df_bat_wi = df_bat_wi.drop_duplicates(subset='player', keep='first')
df_bat_wi
# Out:
#                     player player_role  player_id
# 7          Chadwick Walton          WK         30
# 8              Chris Gayle         BAT         32
# 9           Andre Fletcher          WK         12
# 10           Rovman Powell         BAT        154
# 11        Shimron Hetmeyer         BAT        172
# 12       Carlos Brathwaite     BOWL-AR         29
# 14             Rayad Emrit     BOWL-AR        149
# 371         Marlon Samuels      BAT-AR        121
# 372         Jason Mohammed         BAT         88
# 373          Denesh Ramdin          WK         50
# 375             Keemo Paul     BOWL-AR        102
# 453             Evin Lewis         BAT         59
# 454          Andre Russell     BOWL-AR         13
# 586              Shai Hope          WK        166
# 589         Kieron Pollard      BAT-AR        104
# 590           Darren Bravo         BAT         43
# 593           Fabian Allen      BAT-AR         60
# 611        Nicholas Pooran          WK        137
# 824           Jason Holder     BOWL-AR         87
# 927          John Campbell      BAT-AR         95
# 1224         Lendl Simmons         BAT        110
# 1247          Brandon King         BAT         28
# 1667           Kyle Mayers      BAT-AR        108
# 1892          Dwayne Bravo     BOWL-AR         57
# 1917  Danushka Gunathilaka      BAT-AR         42

# %% [markdown]
# #### Indian Player Details

# %%
df_bat_ind = group.get_group('IND')
df_bat_ind = df_bat_ind[['player', 'player_role', 'player_id']]
df_bat_ind = df_bat_ind.drop_duplicates(subset='player', keep='first')
df_bat_ind
# Out:
#                  player player_role  player_id
# 158        Rohit Sharma         BAT        152
# 159      Shikhar Dhawan         BAT        171
# 160        Suresh Raina         BAT        179
# 161         Virat Kohli         BAT        193
# 162       Manish Pandey         BAT        118
# 163           M S Dhoni          WK        115
# 164       Hardik Pandya      BAT-AR         71
# 242      Dinesh Karthik          WK         55
# 243          Axar Patel     BOWL-AR         21
# 256        Rishabh Pant          WK        151
# 309            KL Rahul          WK         99
# 359       Vijay Shankar      BAT-AR        192
# 361   Washington Sundar      BAT-AR        195
# 602       Krunal Pandya      BAT-AR        105
# 944     Ravindra Jadeja     BOWL-AR        148
# 1019       Shreyas Iyer         BAT        175
# 1130        Shivam Dube     BOWL-AR        173
# 1281       Sanju Samson          WK        161
# 1974       Ishan Kishan          WK         80
# 2248       Prithvi Shaw         BAT        145
# 2251   Suryakumar Yadav         BAT        180
# 2270    Ruturaj Gaikwad         BAT        155
# 2272   Devdutt Padikkal         BAT         51
# 2274        Nitish Rana         BAT        139

# %% [markdown]
# #### Pakistan Player Details

# %%
df_bat_pak = group.get_group('PAK')
df_bat_pak = df_bat_pak[['player', 'player_role', 'player_id']]
df_bat_pak = df_bat_pak.drop_duplicates(subset='player', keep='first')
df_bat_pak
# Out:
#                  player player_role  player_id
# 17         Fakhar Zaman         BAT         63
# 18            Umar Amin      BAT-AR        190
# 19       Mohammad Nawaz     BOWL-AR        132
# 20         Haris Sohail      BAT-AR         72
# 21           Babar Azam         BAT         23
# 22       Sarfaraz Ahmed          WK        162
# 23          Shadab Khan     BOWL-AR        165
# 24        Faheem Ashraf     BOWL-AR         62
# 34        Ahmed Shehzad         BAT          4
# 364       Hussain Talat      BAT-AR         76
# 366        Shoaib Malik      BAT-AR        174
# 367            Asif Ali         BAT         19
# 497     Mohammad Hafeez      BAT-AR        129
# 503          Imad Wasim     BOWL-AR         78
# 556    Sahibzada Farhan         BAT        158
# 703     Mohammad Rizwan          WK        133
# 907         Imam-ul-Haq         BAT         79
# 1054     Iftikhar Ahmed      BAT-AR         77
# 1335          Ahsan Ali         BAT          5
# 1545         Haider Ali         BAT         70
# 1743  Abdullah Shafique         BAT          1
# 1747      Khushdil Shah         BAT        103
# 2051      Sharjeel Khan         BAT        169
# 2206     Sohaib Maqsood         BAT        176
# 2209          Azam Khan          WK         22

# %% [markdown]
# #### Bangladesh Player Details

# %%
df_bat_ban = group.get_group('BAN')
df_bat_ban = df_bat_ban[['player', 'player_role', 'player_id']]
df_bat_ban = df_bat_ban.drop_duplicates(subset='player', keep='first')
df_bat_ban
# Out:
#                   player player_role  player_id
# 130          Zakir Hasan          WK        198
# 131        Soumya Sarkar         BAT        177
# 132      Mushfiqur Rahim          WK        136
# 133         Afif Hossain      BAT-AR          3
# 134          Mahmudullah      BAT-AR        117
# 135        Sabbir Rahman         BAT        156
# 136         Ariful Haque      BAT-AR         16
# 182          Tamim Iqbal         BAT        181
# 185      Mohammad Mithun          WK        130
# 188   Mohammad Saifuddin     BOWL-AR        134
# 189         Mahedi Hasan      BAT-AR        116
# 267            Liton Das          WK        114
# 271         Mehidy Hasan     BOWL-AR        124
# 324            Abu Hider     BOWL-AR          2
# 340      Shakib Al Hasan      BAT-AR        167
# 1137       Mohammad Naim         BAT        131
# 1352        Aminul Islam     BOWL-AR          9
# 2296         Nurul Hasan          WK        140
# 2298      Shamim Hossain      BAT-AR        168

# %%
df
# Out:
#                player player_role team_name opp_name  \
# 0      Martin Guptill         BAT        NZ       WI
# 1         Colin Munro      BAT-AR        NZ       WI
# 2           Tom Bruce      BAT-AR        NZ       WI
# 3       Anaru Kitchen         BAT        NZ       WI
# 4     Kane Williamson         BAT        NZ       WI
# ...               ...         ...       ...      ...
# 4663  Shakib Al Hasan      BAT-AR       BAN      AUS
# 4664     Mahedi Hasan      BAT-AR       BAN      AUS
# 4665      Mahmudullah      BAT-AR       BAN      AUS
# 4666     Afif Hossain      BAT-AR       BAN      AUS
# 4667      Nurul Hasan          WK       BAN      AUS
#
#                               venue  performance  player_id  opp_id  venue_id
# 0         Bay Oval, Mount Maunganui            2        122       8         2
# 1         Bay Oval, Mount Maunganui            2         36       8         2
# 2         Bay Oval, Mount Maunganui            2        187       8         2
# 3         Bay Oval, Mount Maunganui            1         10       8         2
# 4         Bay Oval, Mount Maunganui            1        101       8         2
# ...                             ...          ...        ...     ...       ...
# 4663  Shere Bangla National Stadium            1        167       0        38
# 4664  Shere Bangla National Stadium            1        116       0        38
# 4665  Shere Bangla National Stadium            0        117       0        38
# 4666  Shere Bangla National Stadium            2          3       0        38
# 4667  Shere Bangla National Stadium            1        140       0        38
#
# [3242 rows x 9 columns]

# %%
inputs = df.filter(['player_id', 'opp_id', 'venue_id'])
inputs
# Out:
#       player_id  opp_id  venue_id
# 0           122       8         2
# 1            36       8         2
# 2           187       8         2
# 3            10       8         2
# 4           101       8         2
# ...         ...     ...       ...
# 4663        167       0        38
# 4664        116       0        38
# 4665        117       0        38
# 4666          3       0        38
# 4667        140       0        38
#
# [3242 rows x 3 columns]

# %%
target = df['performance']
target
# Out:
# 0       2
# 1       2
# 2       2
# 3       1
# 4       1
#        ..
# 4663    1
# 4664    1
# 4665    0
# 4666    2
# 4667    1
# Name: performance, Length: 3242, dtype: int32

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

# %%
len(X_train)
# Out:
# 2593

# %%
len(X_test)
# Out:
# 649

# %% [markdown]
# # Training the Model

# %%
model = RandomForestClassifier(n_estimators=200)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
model.predict([[53, 0, 42]]) #Predicting the performance of Dhanjaya De Silva vs Australia team in SCG(Sydney Cricket Ground)
# Out:
# array([1])

# %% [markdown]
# # Model Evaluation

# %%
model.score(X_test,y_test)
# Out:
# 0.7596302003081664

# %%
disp = plot_confusion_matrix(model, X_test, y_test, cmap='Blues', values_format='.3g')

# %%
disp.confusion_matrix
# Out:
# array([[130,  47,  13],
#        [ 27, 243,  28],
#        [ 12,  29, 120]], dtype=int64)
